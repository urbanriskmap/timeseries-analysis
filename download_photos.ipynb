# %%
import sys
sys.executable
sys.path
import torch

# %%
# import chennai_config
# config = chennai_config.config

import jakarta_config
config = jakarta_config.config

from loaders.cognicity_loader import CognicityLoader

load = CognicityLoader(config)

try:
    load.fetch_images()
except:
    pass
    # eh, don't stop
# Out:
# 2019-08-14 17:48:15,409 - DEBUG - CognicityLoader constructed
# 2019-08-14 17:48:15,441 - INFO - Image Url is: https://lh3.googleusercontent.com/8XczuLXQfcbU2xQPWQNk8z_pgcZYaGbVrit6bINxXbZOHXNVOu-mhZpc4nqZb77NktNS5Wr6hdm8iNZovRKx96qzpxt98Q=s480-c
# 2019-08-14 17:48:15,446 - DEBUG - Starting new HTTPS connection (1): lh3.googleusercontent.com:443
# 2019-08-14 17:48:15,498 - DEBUG - https://lh3.googleusercontent.com:443 "GET /8XczuLXQfcbU2xQPWQNk8z_pgcZYaGbVrit6bINxXbZOHXNVOu-mhZpc4nqZb77NktNS5Wr6hdm8iNZovRKx96qzpxt98Q=s480-c HTTP/1.1" 200 232364
# 2019-08-14 17:48:15,522 - DEBUG - Trying to open image
# 2019-08-14 17:48:15,523 - INFO - saving image to path default_jakarta_data/id/62467.jpeg pkey: 62467
# 2019-08-14 17:48:15,524 - INFO - image mode: RGB
# 2019-08-14 17:48:15,558 - INFO - Image Url is: https://lh3.googleusercontent.com/5E6WMOyMsr26hkJ-STT7lp2N_CBk1YMZhcJzSHF2iv0QxQhOhXT74PMh5JQXGfVt7qoDeaiHEvQoZBQlo6snyHGeb9A=s480-c
# ...

# %%
import os
os.path.join("hello", "hi")

# %%
from PIL import Image
import io
import requests
work = requests.get("https://lh3.googleusercontent.com/8XczuLXQfcbU2xQPWQNk8z_pgcZYaGbVrit6bINxXbZOHXNVOu-mhZpc4nqZb77NktNS5Wr6hdm8iNZovRKx96qzpxt98Q=s480-c", stream=True)
b = io.BytesIO(work.content)
im = Image.open(b)
# im.convert("RGB")

# im.convert("RGB")

# im = Image.open(work.raw)
im

# %%
# noWork = requests.get("https://images.detik.com/community/pasma/2017/02/21/1487645667773435642.jpg", stream=True)
# headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0",
#            "Host":"images.detik.com"
#           }
noWork = requests.get("https://images.detik.com/community/pasma/2017/02/19/14874813741214251022.jpg", stream=True)


b = io.BytesIO(noWork.content)
i = Image.open(b)
i
# noWork.raw
# f = noWork.raw.read()
# b = io.BytesIO(f)
# 
# file = open("bad_foto", "wb")
# file.write(b.read())
# file.close()
# noWork.content

# %%
noWork.raw.info()
noWork.raw.read(100)

# %%
noWork = requests.get("https://images.detik.com/community/pasma/2017/02/15/1487175182286001895.jpg", stream=True)
# noWork.raw.seek(15, 0)
noWork.raw.seekable()

# %%
noWork = requests.get("https://images.detik.com/community/pasma/2017/02/15/1487175182286001895.jpg", stream=True)
f = noWork.raw.read()
b = io.BytesIO(f)

# start = b.seek(15,0)
Image.open(b)

# %%
b

# %%
f
